# %%
import os
import pandas as pd

# %% [markdown]
# ## 加载数据

# %%
# 定义数据目录和条件
data_dir = "/home/zhanyu/experiment/data-hh/海航系航班销售过程数据202301-202406-新"
# flight_condition = 'A4tgQv5cqkc='
flight_condition = 'A4tgQv5cqkc='
A_condition = 'xIqe+QQIQXQ='
B_condition = 't+kFcRdzL6o='
C_condition = '/M8gHzjxpNU='

# %%
# 初始化一个空的 DataFrame 用于存储结果
combined_df = pd.DataFrame()

# %%
# 获取所有2023年的CSV文件
csv_files = [file for file in os.listdir(data_dir) if file.endswith('.csv') and file.startswith('2023')]

# 按文件名中的日期部分进行排序
csv_files.sort(key=lambda x: x.split('.')[0])  # 从文件名中提取日期并按字典顺序排序

# 遍历排序后的文件
for file_name in csv_files:
    file_path = os.path.join(data_dir, file_name)
    
    # 读取当前文件
    df = pd.read_csv(file_path)
    
    # 筛选满足条件的行
    filtered_df = df[
        (df['航班号'] == flight_condition) &
        (df['A'] == A_condition) &
        (df['B'] == B_condition) &
        (df['C'] == C_condition)
    ]
    
    # 对筛选后的数据按 '航班日期', 'A', 'B', 'C', '航段', '航班号', '距离天数' 分组，并保留人数最大的行
    filtered_df = filtered_df.loc[filtered_df.groupby(['航班日期', 'A', 'B', 'C', '航段', '航班号', '距离天数'])['人数'].idxmax()]
    
    # 将筛选结果追加到总的 DataFrame 中
    combined_df = pd.concat([combined_df, filtered_df], ignore_index=True)
    
    # 输出当前文件中满足条件的行数
    print(f"{file_name} 中读取到了 {len(filtered_df)} 行数据")

# 查看总的结果
print(f"总共读取到了 {len(combined_df)} 行数据")
# Out:
# 2023-01-01.csv 中读取到了 93 行数据
# 2023-01-02.csv 中读取到了 93 行数据
# 2023-01-03.csv 中读取到了 0 行数据
# 2023-01-04.csv 中读取到了 93 行数据
# 2023-01-05.csv 中读取到了 0 行数据
# 2023-01-06.csv 中读取到了 93 行数据
# 2023-01-07.csv 中读取到了 0 行数据
# 2023-01-08.csv 中读取到了 93 行数据
# 2023-01-09.csv 中读取到了 93 行数据
# 2023-01-10.csv 中读取到了 0 行数据
# 2023-01-11.csv 中读取到了 93 行数据
# 2023-01-12.csv 中读取到了 0 行数据
# 2023-01-13.csv 中读取到了 93 行数据
# 2023-01-14.csv 中读取到了 0 行数据
# 2023-01-15.csv 中读取到了 93 行数据
# 2023-01-16.csv 中读取到了 93 行数据
# 2023-01-17.csv 中读取到了 0 行数据
# 2023-01-18.csv 中读取到了 93 行数据
# 2023-01-19.csv 中读取到了 0 行数据
# 2023-01-20.csv 中读取到了 93 行数据
# 2023-01-21.csv 中读取到了 0 行数据
# 2023-01-22.csv 中读取到了 93 行数据
# 2023-01-23.csv 中读取到了 93 行数据
# 2023-01-24.csv 中读取到了 0 行数据
# 2023-01-25.csv 中读取到了 93 行数据
# 2023-01-26.csv 中读取到了 0 行数据
# 2023-01-27.csv 中读取到了 93 行数据
# 2023-01-28.csv 中读取到了 0 行数据
# 2023-01-29.csv 中读取到了 93 行数据
# 2023-01-30.csv 中读取到了 93 行数据
# 2023-01-31.csv 中读取到了 0 行数据
# 2023-02-01.csv 中读取到了 93 行数据
# 2023-02-02.csv 中读取到了 0 行数据
# 2023-02-03.csv 中读取到了 93 行数据
# 2023-02-04.csv 中读取到了 0 行数据
# 2023-02-05.csv 中读取到了 93 行数据
# 2023-02-06.csv 中读取到了 93 行数据
# 2023-02-07.csv 中读取到了 0 行数据
# 2023-02-08.csv 中读取到了 93 行数据
# 2023-02-09.csv 中读取到了 0 行数据
# 2023-02-10.csv 中读取到了 93 行数据
# 2023-02-11.csv 中读取到了 0 行数据
# 2023-02-12.csv 中读取到了 93 行数据
# 2023-02-13.csv 中读取到了 93 行数据
# 2023-02-14.csv 中读取到了 0 行数据
# 2023-02-15.csv 中读取到了 93 行数据
# 2023-02-16.csv 中读取到了 0 行数据
# 2023-02-17.csv 中读取到了 93 行数据
# 2023-02-18.csv 中读取到了 0 行数据
# 2023-02-19.csv 中读取到了 93 行数据
# 2023-02-20.csv 中读取到了 93 行数据
# 2023-02-21.csv 中读取到了 0 行数据
# 2023-02-22.csv 中读取到了 18 行数据
# 2023-02-23.csv 中读取到了 0 行数据
# 2023-02-24.csv 中读取到了 93 行数据
# 2023-02-25.csv 中读取到了 0 行数据
# 2023-02-26.csv 中读取到了 93 行数据
# 2023-02-27.csv 中读取到了 93 行数据
# 2023-02-28.csv 中读取到了 0 行数据
# 2023-03-01.csv 中读取到了 93 行数据
# 2023-03-02.csv 中读取到了 0 行数据
# 2023-03-03.csv 中读取到了 93 行数据
# 2023-03-04.csv 中读取到了 0 行数据
# 2023-03-05.csv 中读取到了 93 行数据
# 2023-03-06.csv 中读取到了 9 行数据
# 2023-03-07.csv 中读取到了 0 行数据
# 2023-03-08.csv 中读取到了 9 行数据
# 2023-03-09.csv 中读取到了 0 行数据
# 2023-03-10.csv 中读取到了 15 行数据
# 2023-03-11.csv 中读取到了 0 行数据
# 2023-03-12.csv 中读取到了 93 行数据
# 2023-03-13.csv 中读取到了 9 行数据
# 2023-03-14.csv 中读取到了 0 行数据
# 2023-03-15.csv 中读取到了 9 行数据
# 2023-03-16.csv 中读取到了 0 行数据
# 2023-03-17.csv 中读取到了 9 行数据
# 2023-03-18.csv 中读取到了 0 行数据
# 2023-03-19.csv 中读取到了 93 行数据
# 2023-03-20.csv 中读取到了 12 行数据
# 2023-03-21.csv 中读取到了 0 行数据
# 2023-03-22.csv 中读取到了 15 行数据
# 2023-03-23.csv 中读取到了 0 行数据
# 2023-03-24.csv 中读取到了 18 行数据
# 2023-03-25.csv 中读取到了 0 行数据
# 2023-03-26.csv 中读取到了 0 行数据
# 2023-03-27.csv 中读取到了 0 行数据
# 2023-03-28.csv 中读取到了 0 行数据
# 2023-03-29.csv 中读取到了 0 行数据
# 2023-03-30.csv 中读取到了 0 行数据
# 2023-03-31.csv 中读取到了 0 行数据
# 2023-04-01.csv 中读取到了 0 行数据
# 2023-04-02.csv 中读取到了 0 行数据
# 2023-04-03.csv 中读取到了 0 行数据
# 2023-04-04.csv 中读取到了 0 行数据
# 2023-04-05.csv 中读取到了 0 行数据
# 2023-04-06.csv 中读取到了 0 行数据
# 2023-04-07.csv 中读取到了 0 行数据
# 2023-04-08.csv 中读取到了 0 行数据
# 2023-04-09.csv 中读取到了 0 行数据
# 2023-04-10.csv 中读取到了 0 行数据
# 2023-04-11.csv 中读取到了 0 行数据
# 2023-04-12.csv 中读取到了 0 行数据
# 2023-04-13.csv 中读取到了 0 行数据
# 2023-04-14.csv 中读取到了 0 行数据
# 2023-04-15.csv 中读取到了 0 行数据
# 2023-04-16.csv 中读取到了 0 行数据
# 2023-04-17.csv 中读取到了 0 行数据
# 2023-04-18.csv 中读取到了 0 行数据
# 2023-04-19.csv 中读取到了 0 行数据
# 2023-04-20.csv 中读取到了 0 行数据
# 2023-04-21.csv 中读取到了 0 行数据
# 2023-04-22.csv 中读取到了 0 行数据
# 2023-04-23.csv 中读取到了 0 行数据
# 2023-04-24.csv 中读取到了 0 行数据
# 2023-04-25.csv 中读取到了 0 行数据
# 2023-04-26.csv 中读取到了 0 行数据
# 2023-04-27.csv 中读取到了 0 行数据
# 2023-04-28.csv 中读取到了 0 行数据
# 2023-04-29.csv 中读取到了 0 行数据
# 2023-04-30.csv 中读取到了 0 行数据
# 2023-05-01.csv 中读取到了 0 行数据
# 2023-05-02.csv 中读取到了 0 行数据
# 2023-05-03.csv 中读取到了 0 行数据
# 2023-05-04.csv 中读取到了 0 行数据
# 2023-05-05.csv 中读取到了 0 行数据
# 2023-05-06.csv 中读取到了 0 行数据
# 2023-05-07.csv 中读取到了 0 行数据
# 2023-05-08.csv 中读取到了 0 行数据
# 2023-05-09.csv 中读取到了 0 行数据
# 2023-05-10.csv 中读取到了 0 行数据
# 2023-05-11.csv 中读取到了 0 行数据
# 2023-05-12.csv 中读取到了 0 行数据
# 2023-05-13.csv 中读取到了 0 行数据
# 2023-05-14.csv 中读取到了 0 行数据
# 2023-05-15.csv 中读取到了 0 行数据
# 2023-05-16.csv 中读取到了 0 行数据
# 2023-05-17.csv 中读取到了 0 行数据
# 2023-05-18.csv 中读取到了 0 行数据
# 2023-05-19.csv 中读取到了 0 行数据
# 2023-05-20.csv 中读取到了 0 行数据
# 2023-05-21.csv 中读取到了 0 行数据
# 2023-05-22.csv 中读取到了 0 行数据
# 2023-05-23.csv 中读取到了 0 行数据
# 2023-05-24.csv 中读取到了 0 行数据
# 2023-05-25.csv 中读取到了 0 行数据
# 2023-05-26.csv 中读取到了 0 行数据
# 2023-05-27.csv 中读取到了 0 行数据
# 2023-05-28.csv 中读取到了 0 行数据
# 2023-05-29.csv 中读取到了 0 行数据
# 2023-05-30.csv 中读取到了 0 行数据
# 2023-05-31.csv 中读取到了 0 行数据
# 2023-06-01.csv 中读取到了 0 行数据
# 2023-06-02.csv 中读取到了 0 行数据
# 2023-06-03.csv 中读取到了 0 行数据
# 2023-06-04.csv 中读取到了 0 行数据
# 2023-06-05.csv 中读取到了 0 行数据
# 2023-06-06.csv 中读取到了 0 行数据
# 2023-06-07.csv 中读取到了 0 行数据
# 2023-06-08.csv 中读取到了 0 行数据
# 2023-06-09.csv 中读取到了 0 行数据
# 2023-06-10.csv 中读取到了 0 行数据
# 2023-06-11.csv 中读取到了 0 行数据
# 2023-06-12.csv 中读取到了 0 行数据
# 2023-06-13.csv 中读取到了 0 行数据
# 2023-06-14.csv 中读取到了 0 行数据
# 2023-06-15.csv 中读取到了 0 行数据
# 2023-06-16.csv 中读取到了 0 行数据
# 2023-06-17.csv 中读取到了 0 行数据
# 2023-06-18.csv 中读取到了 0 行数据
# 2023-06-19.csv 中读取到了 0 行数据
# 2023-06-20.csv 中读取到了 0 行数据
# 2023-06-21.csv 中读取到了 0 行数据
# 2023-06-22.csv 中读取到了 0 行数据
# 2023-06-23.csv 中读取到了 0 行数据
# 2023-06-24.csv 中读取到了 0 行数据
# 2023-06-25.csv 中读取到了 0 行数据
# 2023-06-26.csv 中读取到了 0 行数据
# 2023-06-27.csv 中读取到了 0 行数据
# 2023-06-28.csv 中读取到了 0 行数据
# 2023-06-29.csv 中读取到了 0 行数据
# 2023-06-30.csv 中读取到了 0 行数据
# 2023-07-01.csv 中读取到了 0 行数据

# %%
# 对 combined_df 数据框按 '航班日期' 升序排序，然后按 '距离天数' 降序排序，并直接修改原始数据框
combined_df.sort_values(by=['航班日期', '距离天数'], ascending=[True, False], inplace=True)

# 假设 df 是你的 DataFrame
combined_df.to_csv('2023-A4tgQv5cqkc=.csv', index=False, encoding='utf-8-sig')
