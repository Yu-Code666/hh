# %%
! which python
# Out:
# /opt/data/envs/machine/bin/python

# %% [markdown]
# ## 加载CSV文件

# %%
import pandas as pd
import numpy as np

# %%
# # 读取CSV文件
# # /Users/zhanyu/code/data-hh/海航系销售结果数据
df = pd.read_csv('../../train_data/海航系销售结果数据_2024-07-01_2024-10-31.csv', index_col=0)

# # 显示前两行数据以确保正确加载
print(df.shape)
print(df.head(5))
# Out:
# (1565445, 16)
#            日期      航段   航班号         航线    a    b    c 宽窄体      起飞时间   布局   机型  \
# 0  2024-07-03  NKGDYG  3004     NKGDYG  NKG  DYG  NaN  窄体  20:10:00  132  319
# 1  2024-07-03  ZHYPEK  3126  KMGZHYPEK  KMG  ZHY  PEK  窄体  15:55:00  164  320
# 2  2024-07-03  KMGZHY  3126  KMGZHYPEK  KMG  ZHY  PEK  窄体  13:00:00  164  320
# 3  2024-07-03  HGHCAN  3153     HGHCAN  HGH  CAN  NaN  窄体  07:05:00  189  321
# 4  2024-07-03  CANHGH  3154     CANHGH  CAN  HGH  NaN  窄体  10:40:00  189  321
#
#    航节数  航节号    航距     客票收入   客流
# 0    1    1  1.50  65290.0  120
# 1    3    2  1.48  76370.0   72
# 2    3    1  1.95  13300.0   28
# 3    1    1  1.60  84290.0  177
# 4    1    1  1.67  73930.0  132

# %%
# 获取第0列的列名
first_column_name = df.columns[2]
print("第0列的列名:", first_column_name)

# 查看第0列的唯一值类型
unique_types = df.iloc[:, 2].apply(type).unique()
print("\n第0列中的数据类型：")
print(unique_types)

# 查看第0列的唯一值
unique_values = df.iloc[:, 2].unique()
print("\n第0列中的唯一值示例：")
print(unique_values[:-1])  # 显示前10个唯一值

# 统计每种类型的数量
type_counts = df.iloc[:, 2].apply(type).value_counts()
print("\n每种类型的数量：")
print(type_counts)
# Out:
# 第0列的列名: 航班号
#
# 第0列中的数据类型：
# [<class 'str'>]
#
# 第0列中的唯一值示例：
# ['3004' '3126' '3153' ... '5005' '5006' '7007']
#
# 每种类型的数量：
# 航班号
# <class 'str'>    1565445
# Name: count, dtype: int64

# %% [markdown]
# ### 修改数据字段名

# %%
# 创建原列名与新列名的映射字典
column_mapping = {
    '日期': 'flt_date',
    '航段': 'segment',
    '航班号': 'flt_no',
    '宽窄体': 'bd_type',
    '起飞时间': 'dep_time',
    '布局': 'cap',
    '机型': 'aircraft',
    '航节数': 'legs',
    '航节号': 'leg_no',
    '航距': 'duration',
    '客票收入': 'tkt_rev',
    '客流': 'pax'
}

# 使用 rename 方法修改列名
df.rename(columns=column_mapping, inplace=True)

# 查看修改后的 DataFrame
print(df.head())
# Out:
#      flt_date segment flt_no         航线    a    b    c bd_type  dep_time  cap  \
# 0  2024-07-03  NKGDYG   3004     NKGDYG  NKG  DYG  NaN      窄体  20:10:00  132
# 1  2024-07-03  ZHYPEK   3126  KMGZHYPEK  KMG  ZHY  PEK      窄体  15:55:00  164
# 2  2024-07-03  KMGZHY   3126  KMGZHYPEK  KMG  ZHY  PEK      窄体  13:00:00  164
# 3  2024-07-03  HGHCAN   3153     HGHCAN  HGH  CAN  NaN      窄体  07:05:00  189
# 4  2024-07-03  CANHGH   3154     CANHGH  CAN  HGH  NaN      窄体  10:40:00  189
#
#   aircraft  legs  leg_no  duration  tkt_rev  pax
# 0      319     1       1      1.50  65290.0  120
# 1      320     3       2      1.48  76370.0   72
# 2      320     3       1      1.95  13300.0   28
# 3      321     1       1      1.60  84290.0  177
# 4      321     1       1      1.67  73930.0  132

# %% [markdown]
# ### 删除航线字段

# %%
# 删除 '航线' 列
df.drop(columns=['航线'], inplace=True)

# 查看删除后的 DataFrame
print(df.head())
# Out:
#      flt_date segment flt_no    a    b    c bd_type  dep_time  cap aircraft  \
# 0  2024-07-03  NKGDYG   3004  NKG  DYG  NaN      窄体  20:10:00  132      319
# 1  2024-07-03  ZHYPEK   3126  KMG  ZHY  PEK      窄体  15:55:00  164      320
# 2  2024-07-03  KMGZHY   3126  KMG  ZHY  PEK      窄体  13:00:00  164      320
# 3  2024-07-03  HGHCAN   3153  HGH  CAN  NaN      窄体  07:05:00  189      321
# 4  2024-07-03  CANHGH   3154  CAN  HGH  NaN      窄体  10:40:00  189      321
#
#    legs  leg_no  duration  tkt_rev  pax
# 0     1       1      1.50  65290.0  120
# 1     3       2      1.48  76370.0   72
# 2     3       1      1.95  13300.0   28
# 3     1       1      1.60  84290.0  177
# 4     1       1      1.67  73930.0  132

# %%
# import pandas as pd
# import glob
# import os

# # 指定目录路径
# directory_path = '../../data-hh/海航系销售结果数据/'

# # 使用 glob 匹配所有 CSV 文件
# csv_files = glob.glob(os.path.join(directory_path, "*.csv"))

# # 检查匹配到的 CSV 文件列表
# print("找到的 CSV 文件:")
# print(csv_files)

# # 读取所有 CSV 文件并合并为一个 DataFrame
# dataframes = []  # 用于存储每个 CSV 文件的 DataFrame
# for file in csv_files:
#     print(f"正在读取文件: {file}")
#     df = pd.read_csv(file)
#     dataframes.append(df)

# # 合并所有 DataFrame（可根据需要选择拼接方式）
# df = pd.concat(dataframes, ignore_index=True)

# # 显示合并后的数据形状和前几行
# print("合并后的数据形状:", df.shape)
# print(df.head())

# %% [markdown]
# ## 拆分 flt_date 为 year, month, day, weekday

# %%
# 将 'flt_date' 列转换为 datetime 格式
df['flt_date'] = pd.to_datetime(df['flt_date'])

# 提取年、月、日和星期几
df['year'] = df['flt_date'].dt.year
df['month'] = df['flt_date'].dt.month
df['day'] = df['flt_date'].dt.day
df['weekday'] = df['flt_date'].dt.weekday  # 0 = Monday, 6 = Sunday

# 删除原始的 'flt_date' 字段
df = df.drop(columns=['flt_date'])


# 查看结果
print(df.head(5))
# Out:
#   segment flt_no    a    b    c bd_type  dep_time  cap aircraft  legs  leg_no  \
# 0  NKGDYG   3004  NKG  DYG  NaN      窄体  20:10:00  132      319     1       1
# 1  ZHYPEK   3126  KMG  ZHY  PEK      窄体  15:55:00  164      320     3       2
# 2  KMGZHY   3126  KMG  ZHY  PEK      窄体  13:00:00  164      320     3       1
# 3  HGHCAN   3153  HGH  CAN  NaN      窄体  07:05:00  189      321     1       1
# 4  CANHGH   3154  CAN  HGH  NaN      窄体  10:40:00  189      321     1       1
#
#    duration  tkt_rev  pax  year  month  day  weekday
# 0      1.50  65290.0  120  2024      7    3        2
# 1      1.48  76370.0   72  2024      7    3        2
# 2      1.95  13300.0   28  2024      7    3        2
# 3      1.60  84290.0  177  2024      7    3        2
# 4      1.67  73930.0  132  2024      7    3        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1565445 entries, 0 to 1565444
# Data columns (total 18 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   segment   1565445 non-null  object
#  1   flt_no    1565445 non-null  object
#  2   a         1565445 non-null  object
#  3   b         1565445 non-null  object
#  4   c         576231 non-null   object
#  5   bd_type   1565445 non-null  object
#  6   dep_time  1565445 non-null  object
#  7   cap       1565445 non-null  int64
#  8   aircraft  1532693 non-null  object
#  9   legs      1565445 non-null  int64
#  10  leg_no    1565445 non-null  int64
#  11  duration  1565445 non-null  float64
#  12  tkt_rev   1565445 non-null  float64
#  13  pax       1565445 non-null  int64
#  14  year      1565445 non-null  int32
#  15  month     1565445 non-null  int32
#  16  day       1565445 non-null  int32
#  17  weekday   1565445 non-null  int32
# dtypes: float64(2), int32(4), int64(4), object(8)
# memory usage: 203.0+ MB

# %% [markdown]
# ## 拆分 dep_time 为 hour, minute, second

# %%
# 拆分 'dep_time' 字段
df[['hour', 'minute', 'second']] = df['dep_time'].str.split(':', expand=True)

# 将拆分的结果转换为整数
df['hour'] = df['hour'].astype(int)
df['minute'] = df['minute'].astype(int)
df['second'] = df['second'].astype(int)

# 删除原始的 'dep_time' 字段
df = df.drop(columns=['dep_time'])

# 查看结果
print(df.head(5))
# Out:
#   segment flt_no    a    b    c bd_type  cap aircraft  legs  leg_no  duration  \
# 0  NKGDYG   3004  NKG  DYG  NaN      窄体  132      319     1       1      1.50
# 1  ZHYPEK   3126  KMG  ZHY  PEK      窄体  164      320     3       2      1.48
# 2  KMGZHY   3126  KMG  ZHY  PEK      窄体  164      320     3       1      1.95
# 3  HGHCAN   3153  HGH  CAN  NaN      窄体  189      321     1       1      1.60
# 4  CANHGH   3154  CAN  HGH  NaN      窄体  189      321     1       1      1.67
#
#    tkt_rev  pax  year  month  day  weekday  hour  minute  second
# 0  65290.0  120  2024      7    3        2    20      10       0
# 1  76370.0   72  2024      7    3        2    15      55       0
# 2  13300.0   28  2024      7    3        2    13       0       0
# 3  84290.0  177  2024      7    3        2     7       5       0
# 4  73930.0  132  2024      7    3        2    10      40       0

# %% [markdown]
# ## 拆分 segment 为 from 和 to

# %%
# 计算 'segment' 列每个值的长度
segment_lengths = df['segment'].apply(len)

# 统计每个长度值出现的次数
length_counts = segment_lengths.value_counts()

# 获取 'segment_length' 列的统计描述
length_description = segment_lengths.describe()

# 打印统计描述
print(length_description)
# Out:
# count    1565445.0
# mean           6.0
# std            0.0
# min            6.0
# 25%            6.0
# 50%            6.0
# 75%            6.0
# max            6.0
# Name: segment, dtype: float64

# %%
# 提取 'segment' 列的前三个字符作为 'from' 列
df['from'] = df['segment'].str[:3]

# 提取 'segment' 列的后三个字符作为 'to' 列
df['to'] = df['segment'].str[-3:]

# 删除原始的 'segment' 字段
df = df.drop(columns=['segment'])

# 查看结果
print(df.head(10))
# Out:
#   flt_no    a    b    c bd_type  cap aircraft  legs  leg_no  duration  ...  \
# 0   3004  NKG  DYG  NaN      窄体  132      319     1       1      1.50  ...
# 1   3126  KMG  ZHY  PEK      窄体  164      320     3       2      1.48  ...
# 2   3126  KMG  ZHY  PEK      窄体  164      320     3       1      1.95  ...
# 3   3153  HGH  CAN  NaN      窄体  189      321     1       1      1.60  ...
# 4   3154  CAN  HGH  NaN      窄体  189      321     1       1      1.67  ...
# 5   3155  HGH  CAN  NaN      窄体  164      320     1       1      1.67  ...
# 6   3156  CAN  HGH  NaN      窄体  164      320     1       1      1.50  ...
# 7   3157  HGH  HRB  NaN      窄体  164      320     1       1      2.52  ...
# 8   3158  HRB  HGH  NaN      窄体  164      320     1       1      2.82  ...
# 9   8038  SHE  CKG  NaN      窄体  164      320     1       1      3.82  ...
#
#    pax  year  month  day  weekday  hour  minute  second  from   to
# 0  120  2024      7    3        2    20      10       0   NKG  DYG
# 1   72  2024      7    3        2    15      55       0   ZHY  PEK
# 2   28  2024      7    3        2    13       0       0   KMG  ZHY
# 3  177  2024      7    3        2     7       5       0   HGH  CAN
# 4  132  2024      7    3        2    10      40       0   CAN  HGH
# 5  151  2024      7    3        2    19       0       0   HGH  CAN
# 6  145  2024      7    3        2    23       5       0   CAN  HGH
# 7  148  2024      7    3        2    20       5       0   HGH  HRB
# 8  148  2024      7    3        2    21      20       0   HRB  HGH
# 9  133  2024      7    1        0    11      20       0   SHE  CKG
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 删除pax异常的行

# %%
# 统计 'pax' 字段中缺失值的行数
missing_pax = df[df['pax'].isna()]

# 统计 'pax' 字段中0值的行数
zero_pax = df[df['pax'] == 0]

# 输出统计结果
num_missing = missing_pax.shape[0]
num_zero = zero_pax.shape[0]

print(df.shape[0])
print(f"缺失值的行数: {num_missing}")
print(f"为0的行数: {num_zero}")
# Out:
# 1565445
# 缺失值的行数: 0
# 为0的行数: 40721

# %%
# 删除 'pax' 字段为缺失值或为0的行
df = df.dropna(subset=['pax'])  # 删除pax列中的缺失值行
df = df[df['pax'] != 0]  # 删除pax列中为0的行

# 查看删除后的DataFrame行数
num_rows_after_cleanup = df.shape[0]
print(f"删除缺失值或为0的行后，DataFrame一共有 {num_rows_after_cleanup} 行")
# Out:
# 删除缺失值或为0的行后，DataFrame一共有 1524724 行

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def remove_outliers(data, col):
    """删除指定列中的异常值"""
    Q1 = data[col].quantile(0.25)  # 第1四分位数
    Q3 = data[col].quantile(0.75)  # 第3四分位数
    IQR = Q3 - Q1  # 四分位距
    lower_bound = Q1 - 1.5 * IQR  # 下限
    upper_bound = Q3 + 1.5 * IQR  # 上限
    
    # 筛选出范围内的数据
    filtered_data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return filtered_data

def plot(data, col):
    """绘制指定列的分布图和箱型图"""
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))
    sns.histplot(data[col], kde=True, ax=ax1)  # 替换 distplot 为 histplot
    sns.boxplot(data[col], ax=ax2)
    plt.tight_layout()
    plt.show()

# # 绘制过滤后的数据分布图和箱型图
# # plot(df, 'pax')
# # 示例数据框
# # 假设 df 是你的数据框
# # 删除 pax 列中的异常值
# df = remove_outliers(df, 'pax')

# 删除 pax 小于 20 的行
df = df[df['pax'] >= 20]


# 绘制过滤后的数据分布图和箱型图
# plot(df, 'pax')

# %%
# 查看删除后的DataFrame行数
num_rows_after_cleanup = df.shape[0]
print(f"删除缺失值或为0的行后，DataFrame一共有 {num_rows_after_cleanup} 行")
# Out:
# 删除缺失值或为0的行后，DataFrame一共有 1465677 行

# %% [markdown]
# ## 处理aircraft

# %%
# 查看 'cap' 列中每个元素的数据类型
print(df['aircraft'].apply(type).value_counts())
# Out:
# aircraft
# <class 'str'>      1465673
# <class 'float'>          4
# Name: count, dtype: int64

# %%
# 统计 'pax' 字段中缺失值的行数
missing_pax = df[df['aircraft'].isna()]

# 统计 'pax' 字段中0值的行数
zero_pax = df[df['aircraft'] == 0]

# 输出统计结果
num_missing = missing_pax.shape[0]
num_zero = zero_pax.shape[0]

print(df.shape[0])
print(f"缺失值的行数: {num_missing}")
print(f"为0的行数: {num_zero}")
# Out:
# 1465677
# 缺失值的行数: 4
# 为0的行数: 0

# %%
# 将 cap 列转换为 Pandas 的 Int64 类型，这种类型支持 NaN 值
# 将 'aircraft' 列转换为字符串类型
# 用 'Unknown' 填充 NaN 值
df['aircraft'] = df['aircraft'].fillna('Unknown')
df['aircraft'] = df['aircraft'].astype(str)

# %%
# 查看 'cap' 列中每个元素的数据类型
print(df['aircraft'].apply(type).value_counts())
# Out:
# aircraft
# <class 'str'>    1465677
# Name: count, dtype: int64

# %% [markdown]
# ## 处理cap

# %%
# 查看 'cap' 列中每个元素的数据类型
print(df['cap'].apply(type).value_counts())
# Out:
# cap
# <class 'int'>    1465677
# Name: count, dtype: int64

# %%
# 统计 'pax' 字段中缺失值的行数
missing_pax = df[df['cap'].isna()]

# 统计 'pax' 字段中0值的行数
zero_pax = df[df['cap'] == 0]

# 输出统计结果
num_missing = missing_pax.shape[0]
num_zero = zero_pax.shape[0]

print(df.shape[0])
print(f"缺失值的行数: {num_missing}")
print(f"为0的行数: {num_zero}")

# 将 'cap' 字段中为0的值修改为 NaN
df.loc[df['cap'] == 0, 'cap'] = np.nan

# 将 'cap' 字段转换为字符串类型
df['cap'] = df['cap'].astype(str)
# Out:
# 1465677
# 缺失值的行数: 0
# 为0的行数: 136553

# %%
# 查看 'cap' 列中每个元素的数据类型
print(df['cap'].apply(type).value_counts())
print(df['aircraft'].apply(type).value_counts())
# Out:
# cap
# <class 'str'>    1465677
# Name: count, dtype: int64
# aircraft
# <class 'str'>    1465677
# Name: count, dtype: int64

# %% [markdown]
# ## 处理duration（待做）

# %%
# 将 'duration' 列中值为 0 的部分替换为 NaN
df.loc[df['duration'] == 0, 'duration'] = np.nan

# %% [markdown]
# ## 处理tkt_rev

# %%
# 统计 'unit_price' 列中为 0 的行数
zero_count = (df['tkt_rev'] == 0).sum()

# 统计 'unit_price' 列中为 NaN 的行数
nan_count = df['tkt_rev'].isna().sum()

# 输出结果
print(f"tkt_rev 列中为 0 的行数: {zero_count}")
print(f"tkt_rev 列中为 NaN 的行数: {nan_count}")
# Out:
# tkt_rev 列中为 0 的行数: 28
# tkt_rev 列中为 NaN 的行数: 0

# %%
df = df[df['tkt_rev'] != 0]

# 计算单价 'unit_price'，即 tkt_rev 除以 pax
df['unit_price'] = df['tkt_rev'] / df['pax']

# 删除 'tkt_rev' 列
df = df.drop(columns=['tkt_rev'])

# %% [markdown]
# ## 保存文件

# %%
# 保存处理后的数据到新的CSV文件
df.to_csv('../../my/hh_result/result_24_7-10-pax>20.csv', index=False)

# %%
# # 将数据按时间段分开
# df_2023_2024_05 = df[(df['year'] == 2023) | ((df['year'] == 2024) & (df['month'] <= 5))]
# df_2024_06 = df[(df['year'] == 2024) & (df['month'] == 6)]

# # 保存2023年1月到2024年5月的数据
# df_2023_2024_05.to_csv('../../data-hh/my/hh_result/result_2023_2024_05.csv', index=False)

# # 保存2024年6月的数据
# df_2024_06.to_csv('../../data-hh/my/hh_result/result_2024_06.csv', index=False)

# %% [markdown]
# ## 统计航段价格信息

# %%
# # 计算每对城市间直航航班的价格统计信息
# price_stats = df.groupby(['from', 'to']).agg({
#     'unit_price': ['mean', 'std', 'count']
# }).round(2)

# # 重命名列
# price_stats.columns = ['平均价格', '价格标准差', '航班数量']

# # 对只有一趟航班的航线,将标准差设为平均价格的十分之一
# single_flight_routes = price_stats['航班数量'] == 1
# price_stats.loc[single_flight_routes, '价格标准差'] = price_stats.loc[single_flight_routes, '平均价格'] / 10

# # 按平均价格降序排序
# price_stats = price_stats.sort_values('平均价格', ascending=False)

# # 显示结果
# print("每对城市间直航航班的价格统计：")
# print(price_stats)

# # 可选：保存结果到CSV文件
# price_stats.to_csv('../../data-hh/my/hh_result/route_price_stats.csv')

# # 输出一些基本统计信息
# print("\n基本统计信息：")
# print(f"航线总数：{len(price_stats)}")
# print(f"最高平均票价航线：{price_stats['平均价格'].max():.2f}")
# print(f"最低平均票价航线：{price_stats['平均价格'].min():.2f}")
# print(f"最大标准差航线：{price_stats['价格标准差'].max():.2f}")
