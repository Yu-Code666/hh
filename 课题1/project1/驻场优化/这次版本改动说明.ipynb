# %% [markdown]
# 首先是更新了pre,express,xgboost,使他们适配真正的海航数据

# %% [markdown]
# 然后是针对真正的海航数据，补充了竞争航班的价格数据
#
# 但是为了方便补充竞争航班数据，补充数据时没有处理flt_date,dep_time,segment,所以补充了数据后还得进行预处理
#
# 完整预处理后文件为./pre_2023-2024_with_comp.csv

# %% [markdown]
# 在补充竞品航线文件中补充了统计航段价格信息
